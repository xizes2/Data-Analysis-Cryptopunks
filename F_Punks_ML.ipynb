# %%
import pandas as pd
import numpy as np

# Treat outliers
from scipy.stats import zscore


# Standardize values------------------------
from sklearn.preprocessing import StandardScaler

# ML models---------------------------------
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster import hierarchy

# Ploting-----------------------------------
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Dimension reduction-----------------------
from sklearn.decomposition import PCA

# Metrics for clusterization----------------
from sklearn.metrics import silhouette_score

# 3D visualization--------------------------
import plotly.graph_objects as go

import numpy as np
from scipy.stats import zscore


# Standardize values------------------------
from sklearn.preprocessing import StandardScaler

# ML models---------------------------------
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster import hierarchy

# Ploting-----------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Dimension reduction-----------------------
from sklearn.decomposition import PCA

# Metrics for clusterization----------------
from sklearn.metrics import silhouette_score

# 3D visualization--------------------------
import plotly.graph_objects as go

# %% [markdown]
# # Preprocessing

# %%
df_transactions = pd.read_csv('transactions_punks_final.csv')
df_traits_dummies = pd.read_csv('transactions_punks_dummies.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-6bba4ab5a3c9> in <module>
# ----> 1 df_transactions = pd.read_csv('transactions_punks_final.csv')
#       2 df_traits_dummies = pd.read_csv('transactions_punks_dummies.csv')
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File transactions_punks_final.csv does not exist: 'transactions_punks_final.csv'

# %%
df_transactions_sold = df_transactions[df_transactions['type'] == 'Sold']
df_dummies_sold = df_traits_dummies[df_traits_dummies['trans_type'] == 'Sold']

# %%
print(df_transactions_sold.columns.tolist())
print(df_dummies_sold.columns.tolist())
# Out:
# ['Unnamed: 0', 'index', 'id', 'punk_id', 'type', 'from', 'to', 'amount_ether', 'amount_$', 'date', 'id.1', 'rarity', 'type.1', 'skin', 'traits']
# ['Unnamed: 0', 'index', 'punk_id', 'trans_type', 'from', 'to', 'amount_ether', 'amount_$', 'date', 'rarity', 'type', 'skin', 'traits', 'traits_counts', "'Bandana'", "'Beanie", "'Beanie'", "'BigBeard", "'BigBeard'", "'BigShades", "'BigShades'", "'BlackLipstick", "'BlackLipstick'", "'BlondeBob", "'BlondeBob'", "'BlondeShort", "'BlondeShort'", "'BlueEyeShadow", "'BlueEyeShadow'", "'BuckTeeth", "'BuckTeeth'", "'Cap", "'Cap'", "'CapForward", "'CapForward'", "'Chinstrap", "'Chinstrap'", "'Choker", "'Choker'", "'Cigarette", "'Cigarette'", "'ClassicShades", "'ClassicShades'", "'ClownEyesBlue", "'ClownEyesBlue'", "'ClownEyesGreen", "'ClownEyesGreen'", "'ClownHairGreen", "'ClownHairGreen'", "'ClownNose", "'ClownNose'", "'CowboyHat", "'CowboyHat'", "'CrazyHair", "'CrazyHair'", "'DarkHair", "'DarkHair'", "'Do-rag", "'Do-rag'", "'Earring", "'Earring'", "'EyeMask", "'EyeMask'", "'EyePatch", "'EyePatch'", "'Fedora", "'Fedora'", "'FrontBeard", "'FrontBeard'", "'FrontBeardDark", "'FrontBeardDark'", "'Frown", "'Frown'", "'FrumpyHair", "'FrumpyHair'", "'Goat", "'Goat'", "'GoldChain", "'GoldChain'", "'GreenEyeShadow", "'GreenEyeShadow'", "'HalfShaved", "'HalfShaved'", "'Handlebars", "'Handlebars'", "'Headband", "'Headband'", "'HiddenBuckTeeth", "'HiddenEarring", "'HiddenEarring'", "'HiddenFrown", "'HiddenHandlebars", "'HiddenLipstick", "'HiddenMole", "'HiddenMole'", "'HiddenMustache", "'HiddenSmile", "'Hoodie", "'Hoodie'", "'HornedRimGlasses", "'HornedRimGlasses'", "'HotLipstick", "'HotLipstick'", "'KnittedCap", "'KnittedCap'", "'LuxuriousBeard", "'LuxuriousBeard'", "'MedicalMask", "'MedicalMask'", "'MessyHair", "'MessyHair'", "'Mohawk", "'Mohawk'", "'MohawkDark", "'MohawkDark'", "'MohawkThin", "'MohawkThin'", "'Mole", "'Mole'", "'Mustache", "'Mustache'", "'Muttonchops", "'Muttonchops'", "'NerdGlasses", "'NerdGlasses'", "'NormalBeard", "'NormalBeard'", "'NormalBeardBlack", "'NormalBeardBlack'", "'OrangeSide", "'OrangeSide'", "'PeakSpike", "'PeakSpike'", "'Pigtails", "'Pigtails'", "'PilotHelmet", "'PilotHelmet'", "'PinkWithHat", "'PinkWithHat'", "'Pipe", "'Pipe'", "'PoliceCap", "'PoliceCap'", "'PurpleEyeShadow", "'PurpleEyeShadow'", "'PurpleHair", "'PurpleHair'", "'PurpleLipstick", "'PurpleLipstick'", "'RedMohawk", "'RedMohawk'", "'RegularShades", "'RegularShades'", "'RosyCheeks", "'RosyCheeks'", "'ShadowBeard", "'ShadowBeard'", "'ShavedHead", "'ShavedHead'", "'SilverChain", "'SilverChain'", "'SmallShades", "'SmallShades'", "'Smile", "'Smile'", "'Spots", "'Spots'", "'StraightHair", "'StraightHair'", "'StraightHairBlonde", "'StraightHairBlonde'", "'StraightHairDark", "'StraightHairDark'", "'StringyHair", "'StringyHair'", "'TassleHat", "'TassleHat'", "'Tiara", "'Tiara'", "'TopHat", "'TopHat'", "'VR", "'VR'", "'VampireHair", "'VampireHair'", "'Vape", "'Vape'", "'WeldingGoggles", "'WeldingGoggles'", "'WildBlonde", "'WildBlonde'", "'WildHair", "'WildHair'", "'WildWhiteHair", "'WildWhiteHair'", 'Bandana', "Bandana'", 'Beanie', "Beanie'", 'BigBeard', "BigBeard'", 'BigShades', "BigShades'", 'BlackLipstick', "BlackLipstick'", 'BlondeBob', "BlondeBob'", 'BlondeShort', "BlondeShort'", 'BlueEyeShadow', "BlueEyeShadow'", "BuckTeeth'", 'Cap', "Cap'", 'CapForward', "CapForward'", 'Chinstrap', "Chinstrap'", 'Choker', "Choker'", 'Cigarette', "Cigarette'", 'ClassicShades', "ClassicShades'", 'ClownEyesBlue', "ClownEyesBlue'", 'ClownEyesGreen', "ClownEyesGreen'", 'ClownHairGreen', "ClownHairGreen'", 'ClownNose', "ClownNose'", 'CowboyHat', "CowboyHat'", 'CrazyHair', "CrazyHair'", 'DGlasses', "DGlasses'", 'DarkHair', "DarkHair'", 'Do-rag', "Do-rag'", 'Earring', "Earring'", "EyeMask'", 'EyePatch', "EyePatch'", 'Fedora', "Fedora'", 'FrontBeard', "FrontBeard'", 'FrontBeardDark', "FrontBeardDark'", 'Frown', "Frown'", 'FrumpyHair', "FrumpyHair'", 'Goat', "Goat'", "GoldChain'", 'GreenEyeShadow', "GreenEyeShadow'", 'HalfShaved', "HalfShaved'", 'Handlebars', "Handlebars'", 'Headband', "Headband'", 'Hoodie', "Hoodie'", 'HornedRimGlasses', "HornedRimGlasses'", 'HotLipstick', "Ho ...

# %%
cols_to_use = df_dummies_sold.columns.difference(df_transactions_sold.columns[2:])

# %%
cols_to_use
# Out:
# Index([''Bandana'', ''Beanie', ''Beanie'', ''BigBeard', ''BigBeard'',
#        ''BigShades', ''BigShades'', ''BlackLipstick', ''BlackLipstick'',
#        ''BlondeBob',
#        ...
#        'VampireHair'', 'Vape'', 'WeldingGoggles', 'WeldingGoggles'',
#        'WildBlonde', 'WildHair', 'WildWhiteHair', 'index', 'traits_counts',
#        'trans_type'],
#       dtype='object', length=350)

# %%
df_fuente_ml = df_transactions_sold.merge(df_dummies_sold[cols_to_use], how='inner', on='index')

# %%
df_fuente_ml.columns.tolist()
# Out:
# ['Unnamed: 0_x',
#  'index',
#  'id',
#  'punk_id',
#  'type',
#  'from',
#  'to',
#  'amount_ether',
#  'amount_$',
#  'date',
#  'id.1',
#  'rarity',
#  'type.1',
#  'skin',
#  'traits',
#  "'Bandana'",
#  "'Beanie",
#  "'Beanie'",
#  "'BigBeard",
#  "'BigBeard'",
#  "'BigShades",
#  "'BigShades'",
#  "'BlackLipstick",
#  "'BlackLipstick'",
#  "'BlondeBob",
#  "'BlondeBob'",
#  "'BlondeShort",
#  "'BlondeShort'",
#  "'BlueEyeShadow",
#  "'BlueEyeShadow'",
#  "'BuckTeeth",
#  "'BuckTeeth'",
#  "'Cap",
#  "'Cap'",
#  "'CapForward",
#  "'CapForward'",
#  "'Chinstrap",
#  "'Chinstrap'",
#  "'Choker",
#  "'Choker'",
#  "'Cigarette",
#  "'Cigarette'",
#  "'ClassicShades",
#  "'ClassicShades'",
#  "'ClownEyesBlue",
#  "'ClownEyesBlue'",
#  "'ClownEyesGreen",
#  "'ClownEyesGreen'",
#  "'ClownHairGreen",
#  "'ClownHairGreen'",
#  "'ClownNose",
#  "'ClownNose'",
#  "'CowboyHat",
#  "'CowboyHat'",
#  "'CrazyHair",
#  "'CrazyHair'",
#  "'DarkHair",
#  "'DarkHair'",
#  "'Do-rag",
#  "'Do-rag'",
#  "'Earring",
#  "'Earring'",
#  "'EyeMask",
#  "'EyeMask'",
#  "'EyePatch",
#  "'EyePatch'",
#  "'Fedora",
#  "'Fedora'",
#  "'FrontBeard",
#  "'FrontBeard'",
#  "'FrontBeardDark",
#  "'FrontBeardDark'",
#  "'Frown",
#  "'Frown'",
#  "'FrumpyHair",
#  "'FrumpyHair'",
#  "'Goat",
#  "'Goat'",
#  "'GoldChain",
#  "'GoldChain'",
#  "'GreenEyeShadow",
#  "'GreenEyeShadow'",
#  "'HalfShaved",
#  "'HalfShaved'",
#  "'Handlebars",
#  "'Handlebars'",
#  "'Headband",
#  "'Headband'",
#  "'HiddenBuckTeeth",
#  "'HiddenEarring",
#  "'HiddenEarring'",
#  "'HiddenFrown",
#  "'HiddenHandlebars",
#  "'HiddenLipstick",
#  "'HiddenMole",
#  "'HiddenMole'",
#  "'HiddenMustache",
#  "'HiddenSmile",
#  "'Hoodie",
#  "'Hoodie'",
#  "'HornedRimGlasses",
#  "'HornedRimGlasses'",
#  "'HotLipstick",
#  "'HotLipstick'",
#  "'KnittedCap",
#  "'KnittedCap'",
#  "'LuxuriousBeard",
#  "'LuxuriousBeard'",
#  "'MedicalMask",
#  "'MedicalMask'",
#  "'MessyHair",
#  "'MessyHair'",
#  "'Mohawk",
#  "'Mohawk'",
#  "'MohawkDark",
#  "'MohawkDark'",
#  "'MohawkThin",
#  "'MohawkThin'",
#  "'Mole",
#  "'Mole'",
#  "'Mustache",
#  "'Mustache'",
#  "'Muttonchops",
#  "'Muttonchops'",
#  "'NerdGlasses",
#  "'NerdGlasses'",
#  "'NormalBeard",
#  "'NormalBeard'",
#  "'NormalBeardBlack",
#  "'NormalBeardBlack'",
#  "'OrangeSide",
#  "'OrangeSide'",
#  "'PeakSpike",
#  "'PeakSpike'",
#  "'Pigtails",
#  "'Pigtails'",
#  "'PilotHelmet",
#  "'PilotHelmet'",
#  "'PinkWithHat",
#  "'PinkWithHat'",
#  "'Pipe",
#  "'Pipe'",
#  "'PoliceCap",
#  "'PoliceCap'",
#  "'PurpleEyeShadow",
#  "'PurpleEyeShadow'",
#  "'PurpleHair",
#  "'PurpleHair'",
#  "'PurpleLipstick",
#  "'PurpleLipstick'",
#  "'RedMohawk",
#  "'RedMohawk'",
#  "'RegularShades",
#  "'RegularShades'",
#  "'RosyCheeks",
#  "'RosyCheeks'",
#  "'ShadowBeard",
#  "'ShadowBeard'",
#  "'ShavedHead",
#  "'ShavedHead'",
#  "'SilverChain",
#  "'SilverChain'",
#  "'SmallShades",
#  "'SmallShades'",
#  "'Smile",
#  "'Smile'",
#  "'Spots",
#  "'Spots'",
#  "'StraightHair",
#  "'StraightHair'",
#  "'StraightHairBlonde",
#  "'StraightHairBlonde'",
#  "'StraightHairDark",
#  "'StraightHairDark'",
#  "'StringyHair",
#  "'StringyHair'",
#  "'TassleHat",
#  "'TassleHat'",
#  "'Tiara",
#  "'Tiara'",
#  "'TopHat",
#  "'TopHat'",
#  "'VR",
#  "'VR'",
#  "'VampireHair",
#  "'VampireHair'",
#  "'Vape",
#  "'Vape'",
#  "'WeldingGoggles",
#  "'WeldingGoggles'",
#  "'WildBlonde",
#  "'WildBlonde'",
#  "'WildHair",
#  "'WildHair'",
#  "'WildWhiteHair",
#  "'WildWhiteHair'",
#  'Bandana',
#  "Bandana'",
#  'Beanie',
#  "Beanie'",
#  'BigBeard',
#  "BigBeard'",
#  'BigShades',
#  "BigShades'",
#  'BlackLipstick',
#  "BlackLipstick'",
#  'BlondeBob',
#  "BlondeBob'",
#  'BlondeShort',
#  "BlondeShort'",
#  'BlueEyeShadow',
#  "BlueEyeShadow'",
#  "BuckTeeth'",
#  'Cap',
#  "Cap'",
#  'CapForward',
#  "CapForward'",
#  'Chinstrap',
#  "Chinstrap'",
#  'Choker',
#  "Choker'",
#  'Cigarette',
#  "Cigarette'",
#  'ClassicShades',
#  "ClassicShades'",
#  'ClownEyesBlue',
#  "ClownEyesBlue'",
#  'ClownEyesGreen',
#  "ClownEyesGreen'",
#  'ClownHairGreen',
#  "ClownHairGreen'",
#  'ClownNose',
#  "ClownNose'",
#  'CowboyHat',
#  "CowboyHat'",
#  'CrazyHair',
#  "CrazyHair'",
#  'DGlasses',
#  "DGlasses'",
#  'DarkHair',
#  "DarkHair'",
#  'Do-rag',
#  "Do-rag'",
#  'Earring',
#  "Earring'",
#  "EyeMask'",
#  'EyePatch',
#  "EyePatch'",
#  'Fedora',
#  "Fedora'",
#  'FrontBeard',
#  "FrontBeard'",
#  'FrontBeardDark',
#  "FrontBeardDark'",
#  'Frown',
#  "Frown'",
#  'FrumpyHair',
#  "FrumpyHair'",
#  'Goat',
#  "Goat'",
#  "GoldChain'",
#  'GreenEyeShadow',
#  "GreenEyeShadow'",
#  'HalfShaved',
#  "HalfShaved'",
#  'Handlebars',
#  "Handlebars'",
#  'Headband',
#  "Headband'",
#  'Hoodie',
#  "Hoodie'",
#  'HornedRimGlasses',
#  "HornedRimGlasses'",
#  'HotLipstick',
#  "HotLipstick'",
#  'KnittedCap',
#  "KnittedCap'",
#  'LuxuriousBeard',
#  "LuxuriousBeard'",
#  'MedicalMask',
#  "MedicalMask'",
#  'MessyHair',
#  "MessyHair'",
#  'Mohawk',
#  "Mohawk'",
#  'MohawkDark',
#  "MohawkDark'",
#  'MohawkThin',
#  "MohawkThin'",
#  'Mole',
#  "Mole'",
#  'Mustache',
#  "Mustache'",
#  'Muttonchops',
#  "Muttonchops'",
#  'NerdGlasses',
#  "NerdGlasses'",
#  'NormalBeard',
#  "NormalBeard'",
#  'NormalBeardBlack',
#  "NormalBeardBlack'",
#  'OrangeSide',
#  "OrangeSide'",
#  'PeakSpike',
#  "PeakSpike'",
#  'Pigtails',
#  "Pigtails'",
#  'PilotHelmet',
#  "PilotHelmet'",
#  'PinkWithHat',
#  "PinkWithHat'",
#  'Pipe',
#  "Pipe'",
#  'PoliceCap',
#  "PoliceCap'",
#  'PurpleEyeShadow',
#  "PurpleEyeShadow'",
#  'PurpleHair',
#  "PurpleHair'",
#  'PurpleLipstick',
#  "PurpleLipstick'",
#  'RedMohawk',
#  "RedMohawk'",
#  'RegularShades',
#  "RegularShades'",
#  'RosyCheeks',
#  "RosyCheeks'",
#  'ShadowBeard',
#  "ShadowBeard'",
#  'ShavedHead',
#  "ShavedHead'",
#  'SilverChain',
#  "SilverChain'",
#  'SmallShades',
#  "SmallShades'",
#  'Smile',
#  "Smile'",
#  'Spots',
#  "Spots'",
#  'StraightHair',
#  'StraightHairBlonde',
#  "StraightHairBlonde'",
#  'StraightHairDark',
#  "StraightHairDark'",
#  'StringyHair',
#  "StringyHair'",
#  'TassleHat',
#  "TassleHat'",
#  'Tiara',
#  'TopHat',
#  "TopHat'",
#  'Unnamed: 0_y',
#  'VR',
#  "VR'",
#  'VampireHair',
#  "VampireHair'",
#  "Vape'",
#  'WeldingGoggles',
#  "WeldingGoggles'",
#  'WildBlonde',
#  'WildHair',
#  'WildWhiteHair',
#  'traits_counts',
#  'trans_type']

# %%
# Separate date into year, month, date
df_fuente_ml['day'] = df_fuente_ml['date'].apply(lambda x: x.split('-')[2])

# %%
# SOPORTE

df_fuente_ml[df_fuente_ml['punk_id'] == 6397]
# Out:
#        Unnamed: 0_x  index        id  punk_id  type      from        to  \
# 15953        166320  99926  0xf41dd9     6397  Sold  0xA317cd  0x9428e5
# 15954        166337  99941  0x96b2b6     6397  Sold  0x62bdc6  0xa4290d
# 15956        166347  99950  0xcd9644     6397  Sold  0x63a9db  0xca4a5b
# 15957        166354  99957  0x74e716     6397  Sold  0x274008  0x63a9db
# 15958        166358  99960  0x42d6a3     6397  Sold  0xf0f068  0x274008
# 15959        166363  99965  0xf0a5a8     6397  Sold  0x6611fE  0xf0f068
#
#        amount_ether  amount_$        date  id.1  rarity type.1  skin  \
# 15953         31.80  80651.50  2021-07-31  6397  5996.0   Male  Dark
# 15954         24.97  53419.60  2021-04-12  6397  5996.0   Male  Dark
# 15956          1.61    607.40  2020-09-14  6397  5996.0   Male  Dark
# 15957          0.68    138.01  2020-05-14  6397  5996.0   Male  Dark
# 15958          0.66    110.20  2020-01-19  6397  5996.0   Male  Dark
# 15959          0.55     77.69  2020-01-08  6397  5996.0   Male  Dark
#
#                                  traits  'Bandana'  'Beanie'  'BigBeard'  \
# 15953  ['Cap', 'Earring', 'FrontBeard']          0         0           0
# 15954  ['Cap', 'Earring', 'FrontBeard']          0         0           0
# 15956  ['Cap', 'Earring', 'FrontBeard']          0         0           0
# 15957  ['Cap', 'Earring', 'FrontBeard']          0         0           0
# 15958  ['Cap', 'Earring', 'FrontBeard']          0         0           0
# 15959  ['Cap', 'Earring', 'FrontBeard']          0         0           0
#
#        'BigShades'  'BlackLipstick'  'BlondeBob'  'BlondeShort'  \
# 15953            0                0            0              0
# 15954            0                0            0              0
# 15956            0                0            0              0
# 15957            0                0            0              0
# 15958            0                0            0              0
# 15959            0                0            0              0
#
#        'BlueEyeShadow'  'BuckTeeth'  'Cap'  'CapForward'  'Chinstrap'  \
# 15953                0            0      1             0            0
# 15954                0            0      1             0            0
# 15956                0            0      1             0            0
# 15957                0            0      1             0            0
# 15958                0            0      1             0            0
# 15959                0            0      1             0            0
#
#        'Choker'  'Cigarette'  'ClassicShades'  'ClownEyesBlue'  \
# 15953         0            0                0                0
# 15954         0            0                0                0
# 15956         0            0                0                0
# 15957         0            0                0                0
# 15958         0            0                0                0
# 15959         0            0                0                0
#
#        'ClownEyesGreen'  'ClownHairGreen'  'ClownNose'  'CowboyHat'  \
# 15953                 0                 0            0            0
# 15954                 0                 0            0            0
# 15956                 0                 0            0            0
# 15957                 0                 0            0            0
# 15958                 0                 0            0            0
# 15959                 0                 0            0            0
#
# 15959       0            0                  0             0                 0
#
#        'RedMohawk'  'RegularShades'  'RosyCheeks'  'ShadowBeard'  \
# 15953            0                0             0              0
# 15954            0                0             0              0
# 15956            0                0             0              0
# 15957            0                0             0              0
# 15958            0                0             0              0
# 15959            0                0             0              0
#
#        'ShavedHead'  'SilverChain'  'SmallShades'  'Smile'  'Spots'  \
# 15953             0              0              0        0        0
# 15954             0              0              0        0        0
# 15956             0              0              0        0        0
# 15957             0              0              0        0        0
# 15958             0              0              0        0        0
# 15959             0              0              0        0        0
#
#        'StraightHair'  'StraightHairBlonde'  'StraightHairDark'  \
# 15953               0                     0                   0
# 15954               0                     0                   0
# 15956               0                     0                   0
# 15957               0                     0                   0
# 15958               0                     0                   0
# 15959               0                     0                   0
#
#        'StringyHair'  'TassleHat'  'Tiara'  'TopHat'  'VR'  'VampireHair'  \
# 15953              0            0        0         0     0              0
# 15954              0            0        0         0     0              0
# 15956              0            0        0         0     0              0
# 15957              0            0        0         0     0              0
# 15958              0            0        0         0     0              0
# 15959              0            0        0         0     0              0
#
#        'Vape'  'WeldingGoggles'  'WildBlonde'  'WildHair'  'WildWhiteHair'  \
# 15953       0                 0             0           0                0
# 15954       0                 0             0           0                0
# 15956       0                 0             0           0                0
# 15957       0                 0             0           0                0
# 15958       0                 0             0           0                0
# 15959       0                 0             0           0                0
#
#        Unnamed: 0_y  traits_counts trans_type
# 15953        166320              3       Sold
# 15954        166337              3       Sold
# 15956        166347              3       Sold
# 15957        166354              3       Sold
# 15958        166358              3       Sold
# 15959        166363              3       Sold

# %%
df_dummies_sold[df_dummies_sold['punk_id'] == 6397]
# Out:
#         Unnamed: 0  index  punk_id trans_type      from        to  \
# 166320      166320  99926     6397       Sold  0xA317cd  0x9428e5
# 166337      166337  99941     6397       Sold  0x62bdc6  0xa4290d
# 166347      166347  99950     6397       Sold  0x63a9db  0xca4a5b
# 166354      166354  99957     6397       Sold  0x274008  0x63a9db
# 166358      166358  99960     6397       Sold  0xf0f068  0x274008
# 166363      166363  99965     6397       Sold  0x6611fE  0xf0f068
#
#         amount_ether  amount_$        date  rarity  type  skin  \
# 166320         31.80  80651.50  2021-07-31  5996.0  Male  Dark
# 166337         24.97  53419.60  2021-04-12  5996.0  Male  Dark
# 166347          1.61    607.40  2020-09-14  5996.0  Male  Dark
# 166354          0.68    138.01  2020-05-14  5996.0  Male  Dark
# 166358          0.66    110.20  2020-01-19  5996.0  Male  Dark
# 166363          0.55     77.69  2020-01-08  5996.0  Male  Dark
#
#                                 traits  traits_counts  'Bandana'  'Beanie'  \
# 166320  'Cap', 'Earring', 'FrontBeard'              3          0         0
# 166337  'Cap', 'Earring', 'FrontBeard'              3          0         0
# 166347  'Cap', 'Earring', 'FrontBeard'              3          0         0
# 166354  'Cap', 'Earring', 'FrontBeard'              3          0         0
# 166358  'Cap', 'Earring', 'FrontBeard'              3          0         0
# 166363  'Cap', 'Earring', 'FrontBeard'              3          0         0
#
#         'BigBeard'  'BigShades'  'BlackLipstick'  'BlondeBob'  'BlondeShort'  \
#    'BlueEyeShadow'  'BuckTeeth'  'Cap'  'CapForward'  'Chinstrap'  'Choker'  \
# 0                1            0      0             0            0         0
#
#    'Cigarette'  'ClassicShades'  'ClownEyesBlue'  'ClownEyesGreen'  \
# 0            0                0                0                 0
#
#    'ClownHairGreen'  'ClownNose'  'CowboyHat'  'CrazyHair'  'DGlasses'  \
# 0                 0            0            0            0           0
#
#    'DarkHair'  'Do-rag'  'Earring'  'EyeMask'  'EyePatch'  'Fedora'  \
# 0           0         0          0          0           0         0
#
#    'FrontBeard'  'FrontBeardDark'  'Frown'  'FrumpyHair'  'Goat'  'GoldChain'  \
# 0             0                 0        0             0       0            0
#
#    'GreenEyeShadow'  'HalfShaved'  'Handlebars'  'Headband'  \
# 0                 0             0             0           0
#
#    'HiddenBuckTeeth'  'HiddenEarring'  'HiddenFrown'  'HiddenHandlebars'  \
# 0                  0                0              0                   0
#
#    'HiddenLipstick'  'HiddenMole'  'HiddenMustache'  'HiddenSmile'  'Hoodie'  \
# 0                 0             0                 0              0         0
#
#    'HornedRimGlasses'  'HotLipstick'  'KnittedCap'  'LuxuriousBeard'  \
# 0                   0              0             0                 0
#
#    'MedicalMask'  'MessyHair'  'Mohawk'  'MohawkDark'  'MohawkThin'  'Mole'  \
# 0              0            1         0             0             0       0
#
#    'Mustache'  'Muttonchops'  'NerdGlasses'  'NormalBeard'  \
# 0           0              0              0              0
#
#    'NormalBeardBlack'  'OrangeSide'  'PeakSpike'  'Pigtails'  'PilotHelmet'  \
# 0                   0             0            0           0              0
#
#    'PinkWithHat'  'Pipe'  'PoliceCap'  'PurpleEyeShadow'  'PurpleHair'  \
# 0              0       0            0                  0             0
#
#    'PurpleLipstick'  'RedMohawk'  'RegularShades'  'RosyCheeks'  \
# 0                 0            0                0             0
#
#    'ShadowBeard'  'ShavedHead'  'SilverChain'  'SmallShades'  'Smile'  \
# 0              0             0              0              0        0
#
#    'Spots'  'StraightHair'  'StraightHairBlonde'  'StraightHairDark'  \
# 0        0               0                     0                   0
#
#    'StringyHair'  'TassleHat'  'Tiara'  'TopHat'  'VR'  'VampireHair'  'Vape'  \
# 0              0            0        0         0     0              0       0
#
#    'WeldingGoggles'  'WildBlonde'  'WildHair'  'WildWhiteHair'  Unnamed: 0_y  \
# 0                 0             0           0                0            17
#
#    traits_counts trans_type  year month day
# 0              3       Sold  2021    07  14

# %%
df_fuente_ml_aaz = df_fuente_ml[(df_fuente_ml['type.1'] == 'Zombie') | (df_fuente_ml['type.1'] == 'Ape') | (df_fuente_ml['type.1'] == 'Alien')]

# %%
df_fuente_ml_aaz.shape
# Out:
# (135, 116)

# %%
df_fuente_ml_humanos = df_fuente_ml[(df_fuente_ml['type.1'] == 'Male') | (df_fuente_ml['type.1'] == 'Female')]

# %%
df_fuente_ml_humanos.shape
# Out:
# (15829, 116)

# %%
# Get dummies for types female and male
df_fuente_ml_humanos = pd.get_dummies(df_fuente_ml_humanos, columns=['skin'])

# %%
df_fuente_ml_humanos.shape
# Out:
# (15829, 120)

# %%
df_fuente_ml_humanos.head(1)
# Out:
#    Unnamed: 0_x   index        id  punk_id  type      from        to  \
# 0            17  100010  0x953cae     6401  Sold  0x577eBC  0x561786
#
#    amount_ether  amount_$        date  id.1  rarity  \
# 0         19.99   39866.7  2021-07-14  6401  5693.0
#
#                                             traits  'Bandana'  'Beanie'  \
# 0  ['BlackLipstick', 'BlueEyeShadow', 'MessyHair']          0         0
#
#    'BigBeard'  'BigShades'  'BlackLipstick'  'BlondeBob'  'BlondeShort'  \
# 0           0            0                1            0              0
#
#    'BlueEyeShadow'  'BuckTeeth'  'Cap'  'CapForward'  'Chinstrap'  'Choker'  \
# 0                1            0      0             0            0         0
#
#    'Cigarette'  'ClassicShades'  'ClownEyesBlue'  'ClownEyesGreen'  \
# 0            0                0                0                 0
#
#    'ClownHairGreen'  'ClownNose'  'CowboyHat'  'CrazyHair'  'DGlasses'  \
# 0                 0            0            0            0           0
#
#    'DarkHair'  'Do-rag'  'Earring'  'EyeMask'  'EyePatch'  'Fedora'  \
# 0           0         0          0          0           0         0
#
#    'FrontBeard'  'FrontBeardDark'  'Frown'  'FrumpyHair'  'Goat'  'GoldChain'  \
# 0             0                 0        0             0       0            0
#
#    'GreenEyeShadow'  'HalfShaved'  'Handlebars'  'Headband'  \
# 0                 0             0             0           0
#
#    'HiddenBuckTeeth'  'HiddenEarring'  'HiddenFrown'  'HiddenHandlebars'  \
# 0                  0                0              0                   0
#
#    'HiddenLipstick'  'HiddenMole'  'HiddenMustache'  'HiddenSmile'  'Hoodie'  \
# 0                 0             0                 0              0         0
#
#    'HornedRimGlasses'  'HotLipstick'  'KnittedCap'  'LuxuriousBeard'  \
# 0                   0              0             0                 0
#
#    'MedicalMask'  'MessyHair'  'Mohawk'  'MohawkDark'  'MohawkThin'  'Mole'  \
# 0              0            1         0             0             0       0
#
#    'Mustache'  'Muttonchops'  'NerdGlasses'  'NormalBeard'  \
# 0           0              0              0              0
#
#    'NormalBeardBlack'  'OrangeSide'  'PeakSpike'  'Pigtails'  'PilotHelmet'  \
# 0                   0             0            0           0              0
#
#    'PinkWithHat'  'Pipe'  'PoliceCap'  'PurpleEyeShadow'  'PurpleHair'  \
# 0              0       0            0                  0             0
#
#    'PurpleLipstick'  'RedMohawk'  'RegularShades'  'RosyCheeks'  \
# 0                 0            0                0             0
#
#    'ShadowBeard'  'ShavedHead'  'SilverChain'  'SmallShades'  'Smile'  \
# 0              0             0              0              0        0
#
#    'Spots'  'StraightHair'  'StraightHairBlonde'  'StraightHairDark'  \
# 0        0               0                     0                   0
#
#    'StringyHair'  'TassleHat'  'Tiara'  'TopHat'  'VR'  'VampireHair'  'Vape'  \
# 0              0            0        0         0     0              0       0
#
#    'WeldingGoggles'  'WildBlonde'  'WildHair'  'WildWhiteHair'  Unnamed: 0_y  \
# 0                 0             0           0                0            17
#
#    traits_counts trans_type  year month day  type.1_Female  type.1_Male  \
# 0              3       Sold  2021    07  14              1            0
#
#    skin_Albino  skin_Dark  skin_Light  skin_Mid
# 0            0          0           0         1

# %%
# 25%        0.000000      0.000000        0.000000              0.000000
# 50%        0.000000      0.000000        0.000000              0.000000
# 75%        0.000000      0.000000        0.000000              0.000000
# max        1.000000      1.000000        1.000000              1.000000
#
#        'StraightHairDark'  'StringyHair'   'TassleHat'       'Tiara'  \
# count        15829.000000   15829.000000  15829.000000  15829.000000
# mean             0.015541       0.059511      0.013077      0.004043
# std              0.123695       0.236586      0.113609      0.063460
# min              0.000000       0.000000      0.000000      0.000000
# 25%              0.000000       0.000000      0.000000      0.000000
# 50%              0.000000       0.000000      0.000000      0.000000
# 75%              0.000000       0.000000      0.000000      0.000000
# max              1.000000       1.000000      1.000000      1.000000
#
#            'TopHat'          'VR'  'VampireHair'        'Vape'  \
# count  15829.000000  15829.000000   15829.000000  15829.000000
# mean       0.010424      0.031019       0.020658      0.022427
# std        0.101567      0.173375       0.142242      0.148073
# min        0.000000      0.000000       0.000000      0.000000
# 25%        0.000000      0.000000       0.000000      0.000000
# 50%        0.000000      0.000000       0.000000      0.000000
# 75%        0.000000      0.000000       0.000000      0.000000
# max        1.000000      1.000000       1.000000      1.000000
#
#        'WeldingGoggles'  'WildBlonde'    'WildHair'  'WildWhiteHair'  \
# count      15829.000000  15829.000000  15829.000000     15829.000000
# mean           0.005559      0.007202      0.042896         0.009539
# std            0.074356      0.084561      0.202629         0.097206
# min            0.000000      0.000000      0.000000         0.000000
# 25%            0.000000      0.000000      0.000000         0.000000
# 50%            0.000000      0.000000      0.000000         0.000000
# 75%            0.000000      0.000000      0.000000         0.000000
# max            1.000000      1.000000      1.000000         1.000000
#
#        traits_counts  type.1_Female   type.1_Male
# count   15829.000000   15829.000000  15829.000000
# mean        2.845916       0.333312      0.666688
# std         0.864572       0.471412      0.471412
# min         0.000000       0.000000      0.000000
# 25%         2.000000       0.000000      0.000000
# 50%         3.000000       0.000000      1.000000
# 75%         3.000000       1.000000      1.000000
# max         9.000000       1.000000      1.000000

# %% [markdown]
# ## 1 - Sin tratamiento de outliers
#     - Standardize values
#     - Apply PCA (on other model)
#     - Apply elbow method to find best k
#     - Apply kmeans
#     - Predic labels
#     - Inertia y Silhouette scores
#     - Identificar/caracterizar grupos
#     - Plot points and centroids (when using PCA)

# %%
# Standardize values
scaler = StandardScaler()
df_ml_humanos_1_std = scaler.fit_transform(df_fuente_ml_humanos_1)

# %%
# Create sum of squared error list to hold this values (inertia_) in order to see what´s the best value for k (Elbow Method)
sse = []
for k in range(1, 11):
    classifier_kmeans = KMeans(n_clusters=k)
    classifier_kmeans.fit(df_ml_humanos_1_std)
    sse.append(classifier_kmeans.inertia_)

# %%
plt.plot(range(1, 11), sse)
plt.show()

# %% [markdown]
# Primera question encontrada: el metodo elbow no hace un elbow muy claro, lo que nos dice que el modelo no puede diferencias muy bien los grupos.
# Voy seguir para ver que score tendremos.

# %%
classifier_kmeans = KMeans(n_clusters=2)
classifier_kmeans.fit(df_ml_humanos_1_std)
# Out:
# KMeans(n_clusters=2)

# %%
classifier_kmeans.predict(df_ml_humanos_1_std)
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %% [markdown]
# **Inertia:**
#
# Inertia measures how well a dataset was clustered by K-Means. It is calculated by measuring the distance between each data point and its centroid, squaring this distance, and summing these squares across one cluster.
#
# A good model is one with low inertia and a low number of clusters (K).
#
# **Silhouette Score:**
#
# The value of Silhouette score varies from -1 to 1. If the score is 1, the cluster is dense and well-separated than other clusters. A value near 0 represents overlapping clusters with samples very close to the decision boundary of the neighbouring clusters. A negative score [-1, 0] indicate that the samples might have got assigned to the wrong clusters.

# %%
inertia = classifier_kmeans.inertia_
silhouette = silhouette_score(df_ml_humanos_1_std, classifier_kmeans.labels_)

print(f'Inertia: {inertia:.3f}')
print(f'Silhouette Score: {silhouette}')
# Out:
# Inertia: 1624174.519
# Silhouette Score: 0.05832778523406271

# %% [markdown]
# Resultados muy malos: Inertia alto y silhouette muy bajo, lo que significa que los puntos están distantes de los centroids y los grupos sin mucha definicion entre ellos.

# %%
# Print labels count
print(f'Label 0: {classifier_kmeans.labels_.tolist().count(0)}')
print(f'Label 1: {classifier_kmeans.labels_.tolist().count(1)}')
print(f'Sum of all labels: {len(classifier_kmeans.labels_.tolist())}')
# Out:
# Label 0: 5276
# Label 1: 10553
# Sum of all labels: 15829

# %%
# Add 'labels' column on original pre-processed df
df_fuente_ml_humanos_1['Labels'] = classifier_kmeans.labels_

# %%
# Group by Labels in order to withdraw first conclusions about it
df_fuente_ml_humanos_1.groupby('Labels').mean()
# Out:
#             amount_$       rarity  'Bandana'  'Beanie'  'BigBeard'  \
# Labels
# 0       54113.265076  4636.270091   0.052691  0.000000    0.000000
# 1       50399.997854  5618.523074   0.056287  0.008623    0.020563
#
#         'BigShades'  'BlackLipstick'  'BlondeBob'  'BlondeShort'  \
# Labels
# 0          0.035823         0.181956     0.027104        0.02862
# 1          0.060646         0.000000     0.000000        0.00000
#
#         'BlueEyeShadow'  'BuckTeeth'     'Cap'  'CapForward'  'Chinstrap'  \
# Labels
# 0              0.075625     0.000000  0.021418      0.000000     0.000000
# 1              0.000000     0.007865  0.035440      0.042168     0.056287
#
#         'Choker'  'Cigarette'  'ClassicShades'  'ClownEyesBlue'  \
# Labels
# 0       0.011372     0.105383         0.053829         0.067096
# 1       0.000000     0.089832         0.059320         0.024448
#
#         'ClownEyesGreen'  'ClownHairGreen'  'ClownNose'  'CowboyHat'  \
# Labels
# 0               0.069939          0.018575     0.016869     0.000000
# 1               0.022363          0.014593     0.022174     0.020089
#
#         'CrazyHair'  'DGlasses'  'DarkHair'  'Do-rag'  'Earring'  'EyeMask'  \
# Labels
# 0          0.040182    0.019712    0.047953  0.000000   0.255876   0.018764
# 1          0.030323    0.022742    0.000000  0.056477   0.260021   0.037904
#
#         'EyePatch'  'Fedora'  'FrontBeard'  'FrontBeardDark'   'Frown'  \
# Labels
# 0         0.020470  0.000000       0.00000           0.00000  0.000000
# 1         0.061025  0.033166       0.04937           0.04918  0.046717
#
#         'FrumpyHair'    'Goat'  'GoldChain'  'GreenEyeShadow'  'HalfShaved'  \
# Labels
# 0           0.035633  0.000000     0.011372          0.063874      0.035633
# 1           0.050602  0.053824     0.014119          0.000000      0.000000
#
#         'Handlebars'  'Headband'  'HiddenBuckTeeth'  'HiddenEarring'  \
# Labels
# 0           0.000000    0.025398                0.0         0.103298
# 1           0.045485    0.052592                0.0         0.012319
#
#         'HiddenFrown'  'HiddenHandlebars'  'HiddenLipstick'  'HiddenMole'  \
# Labels
# 0            0.000000            0.000000          0.005118      0.001327
# 1            0.007581            0.000663          0.000000      0.004928
#
#         'HiddenMustache'  'HiddenSmile'  'Hoodie'  'HornedRimGlasses'  \
# Labels
# 0                0.00000       0.000000   0.00000            0.039613
# 1                0.00019       0.004169   0.03165            0.065005
#
#         'HotLipstick'  'KnittedCap'  'LuxuriousBeard'  'MedicalMask'  \
# Labels
# 0            0.170205      0.033359           0.00000       0.015163
# 1            0.000000      0.047759           0.03364       0.015920
#
#         'MessyHair'  'Mohawk'  'MohawkDark'  'MohawkThin'    'Mole'  \
# Labels
# 0          0.034117  0.051933      0.052312      0.046816  0.091736
# 1          0.050128  0.043495      0.043210      0.053255  0.070217
#
#         'Mustache'  'Muttonchops'  'NerdGlasses'  'NormalBeard'  \
# Labels
# 0         0.000000       0.000000       0.050986       0.000000
# 1         0.051739       0.054297       0.060931       0.050886
#
#         'NormalBeardBlack'  'OrangeSide'  'PeakSpike'  'Pigtails'  \
# Labels
# 0                 0.000000        0.0163     0.000000    0.020091
# 1                 0.039231        0.0000     0.045295    0.000000
#
#         'PilotHelmet'  'PinkWithHat'    'Pipe'  'PoliceCap'  \
# Labels
# 0             0.01232       0.021228  0.032221     0.000000
# 1             0.00000       0.000000  0.028902     0.028238
#
#         'PurpleEyeShadow'  'PurpleHair'  'PurpleLipstick'  'RedMohawk'  \
# Labels
# 0                0.078279      0.000000          0.170205     0.035064
# 1                0.000000      0.025206          0.000000     0.000000
#
#         'RegularShades'  'RosyCheeks'  'ShadowBeard'  'ShavedHead'  \
# Labels
# 0              0.039045      0.016300       0.000000      0.000000
# 1              0.058751      0.010424       0.082631      0.055434
#
#         'SilverChain'  'SmallShades'   'Smile'   'Spots'  'StraightHair'  \
# Labels
# 0            0.013647        0.00000  0.000000  0.016679        0.044352
# 1            0.023500        0.06112  0.034303  0.011276        0.000000
#
#         'StraightHairBlonde'  'StraightHairDark'  'StringyHair'  'TassleHat'  \
# Labels
# 0                   0.038097            0.046626       0.059325     0.039234
# 1                   0.000000            0.000000       0.059604     0.000000
#
#         'Tiara'  'TopHat'      'VR'  'VampireHair'    'Vape'  \
# Labels
# 0       0.01213  0.000000  0.021039       0.000000  0.021986
# 1       0.00000  0.015635  0.036009       0.030986  0.022648
#
#         'WeldingGoggles'  'WildBlonde'  'WildHair'  'WildWhiteHair'  \
# Labels
# 0               0.016679      0.021607    0.036391          0.02862
# 1               0.000000      0.000000    0.046148          0.00000
#
#         traits_counts  type.1_Female  type.1_Male  skin_Albino  skin_Dark  \
# Labels
# 0            2.894617            1.0          0.0     0.097991   0.306293
# 1            2.821567            0.0          1.0     0.090685   0.312044
#
#         skin_Light  skin_Mid
# Labels
# 0         0.283738  0.311979
# 1         0.301526  0.295745

# %% [markdown]
# # 2 - Con tratamiento de outliers

# %%
# Convert year, month, day from str to numeric
df_fuente_ml_humanos_1['day'] = pd.to_numeric(df_fuente_ml_humanos_1['day'])

# %%
# Remove outliers with standard deviation bigger than 3
df_ml_humanos_2_nooutl = df_fuente_ml_humanos_1[df_fuente_ml_humanos_1['amount_$']<100000]

# %%
#df_fuente_ml_humanos_1.describe()

# %%
# Standardize values
scaler = StandardScaler()
df_ml_humanos_2_std = scaler.fit_transform(df_ml_humanos_2_nooutl)

# %%
# Create sum of squared error list to hold this values (inertia_) in order to see what´s the best value for k (Elbow Method)
sse = []
for k in range(1, 11):
    classifier_kmeans = KMeans(n_clusters=k)
    classifier_kmeans.fit(df_ml_humanos_2_std)
    sse.append(classifier_kmeans.inertia_)

# %%
plt.plot(range(1, 11), sse)
plt.show()

# %%
classifier_kmeans = KMeans(n_clusters=2)
classifier_kmeans.fit(df_ml_humanos_2_std)
# Out:
# KMeans(n_clusters=2)

# %%
classifier_kmeans.predict(df_ml_humanos_2_std)
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
inertia = classifier_kmeans.inertia_
silhouette = silhouette_score(df_ml_humanos_2_std, classifier_kmeans.labels_)

print(f'Inertia: {inertia:.3f}')
print(f'Silhouette Score: {silhouette}')
# Out:
# Inertia: 1376771.608
# Silhouette Score: 0.07087853277915165

# %% [markdown]
# Pequeña mejora del modelo anterior

# %%
# Check price outliers
px.box(data_frame=df_ml_dummies_humanos, y='amount_$')
# Out:
# <div>                            <div id="adf7ce15-5e8a-4269-b850-1ca84920eb7b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("adf7ce15-5e8a-4269-b850-1ca84920eb7b")) {                    Plotly.newPlot(                        "adf7ce15-5e8a-4269-b850-1ca84920eb7b",                        [{"alignmentgroup": "True", "hovertemplate": "amount_$=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x0": " ", "xaxis": "x", "y": [3.42, 34.17, 3.42, 13.67, 19.42, 317.22, 16.18, 29.13, 48.55, 9.71, 48.55, 0.32, 64.74, 32.37, 74.45, 0.0, 9.71, 19.42, 97.11, 19.42, 113.29, 116.53, 97.11, 97.11, 48.55, 0.0, 9.71, 42.4, 64.74, 64.74, 32.37, 80.92, 161.85, 37.55, 34.64, 74.45, 48.55, 97.11, 14.89, 60.65, 90.97, 30.32, 30.32, 60.65, 60.65, 40.94, 30.32, 69.75, 45.49, 15.16, 64.21, 45.49, 101.59, 30.32, 30.32, 13.63, 13.63, 60.83, 13.63, 62.72, 13.63, 13.63, 13.63, 114.53, 0.0, 54.54, 48.29, 13.63, 13.63, 49.08, 43.25, 81.81, 14.65, 29.31, 43.96, 87.93, 14.65, 73.27, 43.96, 146.54, 87.93, 71.82, 58.62, 73.27, 43.96, 43.96, 58.62, 58.62, 14.65, 0.0, 69.58, 73.27, 17.59, 41.03, 293.09, 14.65, 43.96, 293.09, 14.65, 14.65, 85.0, 87.93, 14.65, 87.93, 14.65, 161.2, 14.65, 32.79, 32.79, 16.4, 57.05, 32.79, 3.28, 81.98, 16.4, 60.63, 16.4, 33.1, 16.4, 16.4, 32.79, 9.84, 50.19, 60.63, 25.57, 60.58, 36.35, 56
# %%
df_fuente_sold.head(1)

df_traits_dummies = pd.read_csv('transactions_punks_dummies.csv')

# SOPORTE

#df_fuente_sold["cantidad_traits"] = df_fuente_sold["traits"].apply(lambda x: len(x.split(",")))
#df_fuente_sold["day"] = df_fuente_sold["date"].apply(lambda x: x.split("-")[2])
df_fuente_sold_humanos = df_fuente_sold[(df_fuente_sold['type.1'] == 'Male') | (df_fuente_sold['type.1'] == 'Female')]

df_fuente_sold_humanos

df_ml_humanos = df_fuente_sold_humanos[["from", "to", "amount_$", "date", "rarity", "type.1", "skin", "Year", "cantidad_traits"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7a1a4cf883f9> in <module>
#      53 import plotly.graph_objects as go
#      54
# ---> 55 df_fuente_sold.head(1)
#      56
#      57 df_traits_dummies = pd.read_csv('transactions_punks_dummies.csv')
#
# NameError: name 'df_fuente_sold' is not defined

# %%
df_traits_dummies.head(1)
# Out:
#    Unnamed: 0  index  punk_id     trans_type      from   to  amount_ether  \
# 0           0      0        1  Bid withdrawn  0xE1E492  NaN          10.0
#
#    amount_$        date  rarity  type  skin           traits  traits_counts  \
# 0   33222.1  2021-08-13  4352.0  Male  Dark  Mohawk', 'Smile              2
#
#    'Bandana'  'Beanie  'Beanie'  'BigBeard  'BigBeard'  'BigShades  \
# 0          0        0         0          0           0           0
#
#    'BigShades'  'BlackLipstick  'BlackLipstick'  'BlondeBob  'BlondeBob'  \
# 0            0               0                0           0            0
#
#    'BlondeShort  'BlondeShort'  'BlueEyeShadow  'BlueEyeShadow'  'BuckTeeth  \
# 0             0              0               0                0           0
#
#    'BuckTeeth'  'Cap  'Cap'  'CapForward  'CapForward'  'Chinstrap  \
# 0            0     0      0            0             0           0
#
#    'Chinstrap'  'Choker  'Choker'  'Cigarette  'Cigarette'  'ClassicShades  \
# 0            0        0         0           0            0               0
#
#    'ClassicShades'  'ClownEyesBlue  'ClownEyesBlue'  'ClownEyesGreen  \
# 0                0               0                0                0
#
#    'ClownEyesGreen'  'ClownHairGreen  'ClownHairGreen'  'ClownNose  \
# 0                 0                0                 0           0
#
#    'ClownNose'  'CowboyHat  'CowboyHat'  'CrazyHair  'CrazyHair'  'DarkHair  \
# 0            0           0            0           0            0          0
#
#    'DarkHair'  'Do-rag  'Do-rag'  'Earring  'Earring'  'EyeMask  'EyeMask'  \
# 0           0        0         0         0          0         0          0
#
#    'EyePatch  'EyePatch'  'Fedora  'Fedora'  'FrontBeard  'FrontBeard'  \
# 0          0           0        0         0            0             0
#
#    'FrontBeardDark  'FrontBeardDark'  'Frown  'Frown'  'FrumpyHair  \
# 0                0                 0       0        0            0
#
#    'FrumpyHair'  'Goat  'Goat'  'GoldChain  'GoldChain'  'GreenEyeShadow  \
# 0             0      0       0           0            0                0
#
#    'GreenEyeShadow'  'HalfShaved  'HalfShaved'  'Handlebars  'Handlebars'  \
# 0                 0            0             0            0             0
#
#    'Headband  'Headband'  'HiddenBuckTeeth  'HiddenEarring  'HiddenEarring'  \
# 0          0           0                 0               0                0
#
#    'HiddenFrown  'HiddenHandlebars  'HiddenLipstick  'HiddenMole  \
# 0             0                  0                0            0
#
#    'HiddenMole'  'HiddenMustache  'HiddenSmile  'Hoodie  'Hoodie'  \
# 0             0                0             0        0         0
#
#    'HornedRimGlasses  'HornedRimGlasses'  'HotLipstick  'HotLipstick'  \
# 0                  0                   0             0              0
#
#    'KnittedCap  'KnittedCap'  'LuxuriousBeard  'LuxuriousBeard'  'MedicalMask  \
# 0            0             0                0                 0             0
#
#    'MedicalMask'  'MessyHair  'MessyHair'  'Mohawk  'Mohawk'  'MohawkDark  \
# 0              0           0            0        0         0            0
#
#    'MohawkDark'  'MohawkThin  'MohawkThin'  'Mole  'Mole'  'Mustache  \
# 0             0            0             0      0       0          0
#
#    'Mustache'  'Muttonchops  'Muttonchops'  'NerdGlasses  'NerdGlasses'  \
# 0           0             0              0             0              0
#
#    'NormalBeard  'NormalBeard'  'NormalBeardBlack  'NormalBeardBlack'  \
# 0             0              0                  0                   0
#
#    'OrangeSide  'OrangeSide'  'PeakSpike  'PeakSpike'  'Pigtails  'Pigtails'  \
# 0            0             0           0            0          0           0
#
#    'PilotHelmet  'PilotHelmet'  'PinkWithHat  'PinkWithHat'  'Pipe  'Pipe'  \
# 0             0              0             0              0      0       0
#
#    'PoliceCap  'PoliceCap'  'PurpleEyeShadow  'PurpleEyeShadow'  'PurpleHair  \
# 0           0            0                 0                  0            0
#
#    'PurpleHair'  'PurpleLipstick  'PurpleLipstick'  'RedMohawk  'RedMohawk'  \
# 0             0                0                 0           0            0
#
#    'RegularShades  'RegularShades'  'RosyCheeks  'RosyCheeks'  'ShadowBeard  \
# 0               0                0            0             0             0
#
#    'ShadowBeard'  'ShavedHead  'ShavedHead'  'SilverChain  'SilverChain'  \
# 0              0            0             0             0              0
#
#    'SmallShades  'SmallShades'  'Smile  'Smile'  'Spots  'Spots'  \
# 0             0              0       1        0       0        0
#
#    'StraightHair  'StraightHair'  'StraightHairBlonde  'StraightHairBlonde'  \
# 0              0               0                    0                     0
#
#    'StraightHairDark  'StraightHairDark'  'StringyHair  'StringyHair'  \
# 0                  0                   0             0              0
#
#    'TassleHat  'TassleHat'  'Tiara  'Tiara'  'TopHat  'TopHat'  'VR  'VR'  \
# 0           0            0       0        0        0         0    0     0
#
#    'VampireHair  'VampireHair'  'Vape  'Vape'  'WeldingGoggles  \
# 0             0              0      0       0                0
#
#    'WeldingGoggles'  'WildBlonde  'WildBlonde'  'WildHair  'WildHair'  \
# 0                 0            0             0          0           0
#
#    'WildWhiteHair  'WildWhiteHair'  Bandana  Bandana'  Beanie  Beanie'  \
# 0               0                0        0         0       0        0
#
#    BigBeard  BigBeard'  BigShades  BigShades'  BlackLipstick  BlackLipstick'  \
# 0         0          0          0           0              0               0
#
#    BlondeBob  BlondeBob'  BlondeShort  BlondeShort'  BlueEyeShadow  \
# 0          0           0            0             0              0
#
#    BlueEyeShadow'  BuckTeeth'  Cap  Cap'  CapForward  CapForward'  Chinstrap  \
# 0               0           0    0     0           0            0          0
#
#    Chinstrap'  Choker  Choker'  Cigarette  Cigarette'  ClassicShades  \
# 0           0       0        0          0           0              0
#
#    ClassicShades'  ClownEyesBlue  ClownEyesBlue'  ClownEyesGreen  \
# 0               0              0               0               0
#
#    ClownEyesGreen'  ClownHairGreen  ClownHairGreen'  ClownNose  ClownNose'  \
# 0                0               0                0          0           0
#
#    CowboyHat  CowboyHat'  CrazyHair  CrazyHair'  DGlasses  DGlasses'  \
# 0          0           0          0           0         0          0
#
#    DarkHair  DarkHair'  Do-rag  Do-rag'  Earring  Earring'  EyeMask'  \
# 0         0          0       0        0        0         0         0
#
#    EyePatch  EyePatch'  Fedora  Fedora'  FrontBeard  FrontBeard'  \
# 0         0          0       0        0           0            0
#
#    FrontBeardDark  FrontBeardDark'  Frown  Frown'  FrumpyHair  FrumpyHair'  \
# 0               0                0      0       0           0            0
#
#    Goat  Goat'  GoldChain'  GreenEyeShadow  GreenEyeShadow'  HalfShaved  \
# 0     0      0           0               0                0           0
#
#    HalfShaved'  Handlebars  Handlebars'  Headband  Headband'  Hoodie  Hoodie'  \
# 0            0           0            0         0          0       0        0
#
#    HornedRimGlasses  HornedRimGlasses'  HotLipstick  HotLipstick'  KnittedCap  \
# 0                 0                  0            0             0           0
#
#    KnittedCap'  LuxuriousBeard  LuxuriousBeard'  MedicalMask  MedicalMask'  \
# 0            0               0                0            0             0
#
#    MessyHair  MessyHair'  Mohawk  Mohawk'  MohawkDark  MohawkDark'  \
# 0          0           0       0        1           0            0
#
#    MohawkThin  MohawkThin'  Mole  Mole'  Mustache  Mustache'  Muttonchops  \
# 0           0            0     0      0         0          0            0
#
#    Muttonchops'  NerdGlasses  NerdGlasses'  NormalBeard  NormalBeard'  \
# 0             0            0             0            0             0
#
#    NormalBeardBlack  NormalBeardBlack'  OrangeSide  OrangeSide'  PeakSpike  \
# 0                 0                  0           0            0          0
#
#    PeakSpike'  Pigtails  Pigtails'  PilotHelmet  PilotHelmet'  PinkWithHat  \
# 0           0         0          0            0             0            0
#
#    PinkWithHat'  Pipe  Pipe'  PoliceCap  PoliceCap'  PurpleEyeShadow  \
# 0             0     0      0          0           0                0
#
#    PurpleEyeShadow'  PurpleHair  PurpleHair'  PurpleLipstick  PurpleLipstick'  \
# 0                 0           0            0               0                0
#
#    RedMohawk  RedMohawk'  RegularShades  RegularShades'  RosyCheeks  \
# 0          0           0              0               0           0
#
#    RosyCheeks'  ShadowBeard  ShadowBeard'  ShavedHead  ShavedHead'  \
# 0            0            0             0           0            0
#
#    SilverChain  SilverChain'  SmallShades  SmallShades'  Smile  Smile'  Spots  \
# 0            0             0            0             0      0       0      0
#
#    Spots'  StraightHair  StraightHairBlonde  StraightHairBlonde'  \
# 0       0             0                   0                    0
#
#    StraightHairDark  StraightHairDark'  StringyHair  StringyHair'  TassleHat  \
# 0                 0                  0            0             0          0
#
#    TassleHat'  Tiara  TopHat  TopHat'  VR  VR'  VampireHair  VampireHair'  \
# 0           0      0       0        0   0    0            0             0
#
#    Vape'  WeldingGoggles  WeldingGoggles'  WildBlonde  WildHair  WildWhiteHair
# 0      0               0                0           0         0              0

# %%
df_ml_dummies_humanos = pd.get_dummies(data=df_ml_humanos, columns=["type.1", "skin"])

# %%
# SOPORTE

#df_ml_dummies_humanos.drop(columns=["date"], axis=1, inplace=True)
#df_ml_dummies_humanos = df_ml_dummies_humanos.astype({'Year':int})

# %%
df_ml_dummies_humanos.head(1)

df_ml_dummies_humanos.describe()
# Out:
#             from        to  amount_$  rarity  Year  cantidad_traits  \
# 104242  0x5b098b  0xc352b5      3.42  3440.0  2017                3
#
#         type.1_Female  type.1_Male  skin_Albino  skin_Dark  skin_Light  \
# 104242              0            1            0          0           0
#
#         skin_Mid
# 104242         1

# %%
df_ml_dummies_humanos.drop(columns=['from', 'to'], axis=1).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15829 entries, 104242 to 72635
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   amount_$         15829 non-null  float64
#  1   rarity           15829 non-null  float64
#  2   Year             15829 non-null  int32
#  3   cantidad_traits  15829 non-null  int64
#  4   type.1_Female    15829 non-null  uint8
#  5   type.1_Male      15829 non-null  uint8
#  6   skin_Albino      15829 non-null  uint8
#  7   skin_Dark        15829 non-null  uint8
#  8   skin_Light       15829 non-null  uint8
#  9   skin_Mid         15829 non-null  uint8
# dtypes: float64(2), int32(1), int64(1), uint8(6)
# memory usage: 649.2 KB

# %%
df_ml_dummies_humanos_nooutl.describe()
# Out:
#             amount_$        rarity          Year  cantidad_traits  \
# count   14027.000000  14027.000000  14027.000000     14027.000000
# mean    44143.221487   5331.482641   2020.190704         2.841591
# std     58666.993410   2784.259130      1.253794         0.809981
# min         0.000000      5.000000   2017.000000         1.000000
# 25%       200.040000   2951.500000   2020.000000         2.000000
# 50%     28235.500000   5461.000000   2021.000000         3.000000
# 75%     60877.600000   7646.000000   2021.000000         3.000000
# max    296870.000000   9998.000000   2021.000000         5.000000
#
#        type.1_Female   type.1_Male  skin_Albino     skin_Dark    skin_Light  \
# count   14027.000000  14027.000000      14027.0  14027.000000  14027.000000
# mean        0.331432      0.668568          0.0      0.342554      0.324873
# std         0.470745      0.470745          0.0      0.474581      0.468344
# min         0.000000      0.000000          0.0      0.000000      0.000000
# 25%         0.000000      0.000000          0.0      0.000000      0.000000
# 50%         0.000000      1.000000          0.0      0.000000      0.000000
# 75%         1.000000      1.000000          0.0      1.000000      1.000000
# max         1.000000      1.000000          0.0      1.000000      1.000000
#
#            skin_Mid
# count  14027.000000
# mean       0.332573
# std        0.471152
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
px.box(data_frame=df_ml_dummies_humanos_nooutl, y='amount_$')
# Out:
# <div>                            <div id="2c95d514-1461-4712-aa5b-7791b8d35a96" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2c95d514-1461-4712-aa5b-7791b8d35a96")) {                    Plotly.newPlot(                        "2c95d514-1461-4712-aa5b-7791b8d35a96",                        [{"alignmentgroup": "True", "hovertemplate": "amount_$=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x0": " ", "xaxis": "x", "y":
, 94.07, 63.16, 94.07, 67.19, 110.2, 75.26, 110.2, 67.19, 175.86, 81.16, 105.51, 105.51, 63.58, 137.98, 137.98, 137.98, 137.98, 175.86, 67.64, 67.64, 105.51, 71.34, 68.88, 221.39, 95.94, 118.08, 54.12, 93.48, 59.04, 61.5, 159.89, 110.7, 393.59, 233.69, 95.94, 81.18, 59.04, 86.1, 147.59, 66.42, 95.94, 71.34, 73.8, 93.48, 61.5, 71.34, 83.64, 24.6, 98.4, 233.69, 95.94, 118.08, 86.1, 95.94, 393.59, 90.61, 375.03, 88.09, 93.13, 98.16, 88.09, 98.16, 375.03, 103.2, 103.2, 98.16, 98.16, 88.09, 103.2, 75.51, 193.81, 98.16, 98.16, 98.16, 98.16, 72.99, 50.34, 103.2, 113.26, 100.68, 98.16, 98.16, 99.28, 99.28, 78.69, 96.85, 242.14, 72.64, 84.75, 82.33, 96.85, 78.69, 53.84, 159.36, 88.3, 107.68, 107.68, 83.99, 60.3, 58.15, 62.45, 213.2, 64.61, 64.61, 49.53, 60.3, 86.14, 111.99, 86.14, 86.14, 46.3, 10.98, 46.3, 109.83, 86.14, 88.3, 66.76, 146.44, 0.0, 64.61, 127.18, 75.01, 12.24, 122.39, 96.73, 17.37, 80.94, 80.94, 78.96, 69.09, 69.09, 69.09, 126.34, 65.14, 71.07, 69.09, 16.98, 78.96, 76.99, 116.47, 92.78, 64.16, 34.62, 86.54, 85.39, 117.69, 207.7, 276.93, 80.77, 115.39, 86.42, 87.69, 101.54, 88.85, 87 ...

# %%
# Apply PCA transformation
pca = PCA(n_components=2)
df_ml_dummies_humanos_pca = pca.fit_transform(df_ml_dummies_humanos_std)

# %%
df_ml_dummies_humanos_pca.shape
# Out:
# (14027, 2)

# %% [markdown]
# # Plot

# %%
df_pca_plot = pd.DataFrame(df_ml_dummies_humanos_pca)

# %%
df_pca_plot = pd.concat([df_pca_plot, pd.DataFrame(classifier_kmeans.labels_, columns=['Label'])], axis=1)
df_pca_plot
# Out:
#               0         1  Label
# 0     -0.794590 -2.774026      1
# 1     -1.332744 -2.746350      1
# 2      2.346876 -2.734889      0
# 3     -1.228621 -0.569805      1
# 4      2.303765 -2.766696      0
# ...         ...       ...    ...
# 14022  2.521828  2.543660      0
# 14023  2.163495  2.376417      0
# 14024 -1.037431  2.388700      1
# 14025  1.893196  2.580997      0
# 14026 -1.065778  2.478843      1
#
# [14027 rows x 3 columns]

# %%
# Plot points and centroids using matplotlib and seaborn
plt.figure(figsize = (10, 6))
sns.scatterplot(data=df_pca_plot, x=df_pca_plot[0], y=df_pca_plot[1], hue='Label')
plt.scatter(classifier_kmeans.cluster_centers_[0][0], classifier_kmeans.cluster_centers_[0][1], c='red', s=100)
plt.scatter(classifier_kmeans.cluster_centers_[1][0], classifier_kmeans.cluster_centers_[1][1], c='blue', s=100)
plt.show()

# %%
classifier_kmeans.cluster_centers_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d725c7d431cf> in <module>
# ----> 1 classifier_kmeans.cluster_centers_
#
# NameError: name 'classifier_kmeans' is not defined
